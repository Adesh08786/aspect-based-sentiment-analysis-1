# %%
import pandas as pd
import nltk
from nltk import word_tokenize

# %%
sen="the food was best but the serving was worst"

# %%
import re
sen = [re.sub(r"[^a-zA-Z0-9]+", ' ', k) for k in sen.split("\n")]
print(sen)
sen2=sen
# Out:
# ['the food was best but the serving was worst']

# %%
sen=word_tokenize(sen[0])

# %%
df=pd.DataFrame(sen,columns=['word'])
df['stopword']=0
df['pos_tag']=''

# %%
from nltk.corpus import stopwords
a=set(stopwords.words('english'))

# %%
df['word_len']=0

# %%
df
# Out:
#       word  stopword pos_tag  word_len
# 0      the         0                 0
# 1     food         0                 0
# 2      was         0                 0
# 3     best         0                 0
# 4      but         0                 0
# 5      the         0                 0
# 6  serving         0                 0
# 7      was         0                 0
# 8    worst         0                 0
#
# [9 rows x 4 columns]

# %%
for i in range(0,len(df)):
    if (df['word'][i]) in a:
        df['stopword'][i]=1
        
        
    else:
        df['stopword'][i]=0
        
        
    if(len(df['word'][i])>3):
        df['word_len'][i]=1
    else:
        df['word_len'][i]=0

# %%
df
# Out:
#       word  stopword pos_tag  word_len
# 0      the         1                 0
# 1     food         0                 1
# 2      was         1                 0
# 3     best         0                 1
# 4      but         1                 0
# 5      the         1                 0
# 6  serving         0                 1
# 7      was         1                 0
# 8    worst         0                 1
#
# [9 rows x 4 columns]

# %%
post_tag=nltk.pos_tag(sen
                     )

# %%
post_tag[0][1]
# Out:
# 'DT'

# %%
df['pos_tag']=post_tag

# %%
next_l=[]
k=0
for i in range(0,len(sen)-1):
    #printi
    next_l.append(sen[i+1])

# %%
next_l
# Out:
# ['food', 'was', 'best', 'but', 'the', 'serving', 'was', 'worst']

# %%
next_l.append("")

# %%
next_l
# Out:
# ['food', 'was', 'best', 'but', 'the', 'serving', 'was', 'worst', '']

# %%
df['next_words']=""

# %%
df['next_words']=next_l

# %%
df['prev_words']=""
prev=[]

# %%
prev.append("")

# %%
for i in range(1,len(sen)):
    #print i
    #print sen[i]
    prev.append(sen[i-1])

# %%
prev
# Out:
# ['', 'the', 'food', 'was', 'best', 'but', 'the', 'serving', 'was']

# %%
df['prev_words']=prev

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
# [9 rows x 6 columns]

# %%
df['pre_word_tag']=""
df['post_word_tag']=""
print(sen)
# Out:
# ['the', 'food', 'was', 'best', 'but', 'the', 'serving', 'was', 'worst']

# %%
import os
a=os.popen("echo '"+sen2[0]+"' > ~/stanford-parser-2012-11-12/stanfordtemp.txt")
parser_out = os.popen("~/stanford-parser-2012-11-12/lexparser.sh ~/stanford-parser-2012-11-12/stanfordtemp.txt")
print(parser_out)
for relation in parser_out:
    print(relation)
# Out:
# <os._wrap_close object at 0x7f15cbf2db00>
# (ROOT
#
#   (S
#
#     (NP (DT the) (NN food))
#
#     (VP (VBD was)
#
#       (ADJP (JJS best))
#
#       (SBAR (CC but)
#
#         (S
#
#           (NP (DT the) (NN serving))
#
#           (VP (VBD was)
#
#             (ADJP (JJS worst))))))))
#
#
#
# det(food-2, the-1)
#
# nsubj(best-4, food-2)
#
# cop(best-4, was-3)
#
# root(ROOT-0, best-4)
#
# cc(worst-9, but-5)
#
# det(serving-7, the-6)
#
# nsubj(worst-9, serving-7)
#
# cop(worst-9, was-8)
#
# ccomp(best-4, worst-9)

# %%
from nltk.tree import Tree

examples = [ '(ROOT (S     (NP (DT the) (NN food))    (VP (VBD was) (ADJP (JJS best)) (SBAR (CC but) (S  (NP (DT the) (NN serving)) (VP (VBD was)       (ADJP (JJS worst))))))))']
head_word=[]

def find_noun_phrases(tree):
    return [subtree for subtree in tree.subtrees(lambda t: t.label()=='NP')]

def find_head_of_np(np):
    noun_tags = ['NN', 'NNS', 'NNP', 'NNPS']
    top_level_trees = [np[i] for i in range(len(np)) if type(np[i]) is Tree]
    ## search for a top-level noun
    top_level_nouns = [t for t in top_level_trees if t.label() in noun_tags]
    if len(top_level_nouns) > 0:
        ## if you find some, pick the rightmost one, just 'cause
        return top_level_nouns[-1][0]
    else:
        ## search for a top-level np
        top_level_nps = [t for t in top_level_trees if t.label()=='NP']
        if len(top_level_nps) > 0:
            ## if you find some, pick the head of the rightmost one, just 'cause
            return find_head_of_np(top_level_nps[-1])
        else:
            ## search for any noun
            nouns = [p[0] for p in np.pos() if p[1] in noun_tags]
            if len(nouns) > 0:
                ## if you find some, pick the rightmost one, just 'cause
                return nouns[-1]
            else:
                ## return the rightmost word, just 'cause
                return np.leaves()[-1]

for example in examples:
    tree = Tree.fromstring(example)
    for np in find_noun_phrases(tree):
       
        print(" ".join(np.leaves()))
        head = find_head_of_np(np)
        
        if head not in head_word:
            
            head_word.append(head)
# Out:
# the food
# the serving

# %%
head_word
# Out:
# ['food', 'serving']

# %%
df['head_word']=0
pos_pre=[]
pos_pre.append("")
pos_post=[]
pos=[]
df['pos']=""

for i in range(0,len(post_tag)-1):
    pos_post.append(post_tag[i+1][1])
pos_post.append("")

for i in range(0,len(post_tag)):
    pos.append(post_tag[i][1])
    
for i in range(1,len(post_tag)):
    pos_pre.append(post_tag[i-1][1])

df['pre_word_tag']=pos_pre
df['post_word_tag']=pos_post
df['pos']=pos

# %%
for i in range(0,len(df)):
   
        

    if (df['word'][i]) in head_word:
        print(df['word'][i])
        df['head_word'][i]=1
    else:
        df['head_word'][i]=0
# Out:
# food
# serving

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words  \
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
#   pre_word_tag post_word_tag  head_word lematized_words ortho_features  \
# 0                         NN          0             the              0
# 1           DT           VBD          1            food              0
# 2           NN           RBS          0              be              0
# 3          VBD            CC          0            best              0
# 4          RBS            DT          0             but              0
# 5           CC            NN          0             the              0
# 6           DT           VBD          1         serving              0
# 7           NN            RB          0              be              0
# 8          VBD                        0             bad              0
#
#   token_freq head_word_tag  pos
# 0          2                 DT
# 1          1            NN   NN
# 2          2                VBD
# 3          1                RBS
# 4          1                 CC
# 5          2                 DT
# 6          1            NN   NN
# 7          2                VBD
# 8          1                 RB
#
# [9 rows x 14 columns]

# %%
t1="she is serving food in the restaurant"
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer() 
for i in range(0,len(sen)):
  
    print(lemmatizer.lemmatize('worst','a'))
# Out:
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad
# bad

# %%
from nltk.corpus import wordnet

morphy_tag = {'NN':wordnet.NOUN,'JJS':wordnet.ADJ,'VBD':wordnet.VERB,'RB':wordnet.ADJ,'VBG':wordnet.VERB}

# %%
morphy_tag
# Out:
# {'JJS': 'a', 'NN': 'n', 'RB': 'a', 'VBD': 'v', 'VBG': 'v'}

# %%
df['lematized_words']='NULL'
lema=[]
from nltk.stem import WordNetLemmatizer 
  
lemmatizer = WordNetLemmatizer() 
for i in range(0,len(sen)):
    c=post_tag[i][1]
    for name in morphy_tag.keys():
        if name == c:
            print(name)
            new=morphy_tag[name]
            print(new)
    lema.append(lemmatizer.lemmatize(post_tag[i][0],new))
# Out:
# NN
# n
# VBD
# v
# NN
# n
# VBD
# v
# RB
# a

# %%
lema
# Out:
# ['the', 'food', 'be', 'best', 'but', 'the', 'serving', 'be', 'bad']

# %%
df['lematized_words']=lema

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words  \
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
#   pre_word_tag post_word_tag  head_word lematized_words ortho_features  \
# 0                         NN          0             the              0
# 1           DT           VBD          1            food              0
# 2           NN           RBS          0              be              0
# 3          VBD            CC          0            best              0
# 4          RBS            DT          0             but              0
# 5           CC            NN          0             the              0
# 6           DT           VBD          1         serving              0
# 7           NN            RB          0              be              0
# 8          VBD                        0             bad              0
#
#   token_freq head_word_tag  pos
# 0          2                 DT
# 1          1            NN   NN
# 2          2                VBD
# 3          1                RBS
# 4          1                 CC
# 5          2                 DT
# 6          1            NN   NN
# 7          2                VBD
# 8          1                 RB
#
# [9 rows x 14 columns]

# %%
df['ortho_features']=''
for i in range(0,len(df)):
    if ((df['word'][i].istitle() == True) or (df['word'][i].isdigit()==True)):
        df['ortho_features'][i]=1
    else:
        df['ortho_features'][i]=0

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words  \
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
#     pre_word_tag  post_word_tag  head_word lematized_words ortho_features
# 0                    (food, NN)          0             the              0
# 1      (the, DT)     (was, VBD)          1            food              0
# 2     (food, NN)    (best, RBS)          0              be              0
# 3     (was, VBD)      (but, CC)          0            best              0
# 4    (best, RBS)      (the, DT)          0             but              0
# 5      (but, CC)  (serving, NN)          0             the              0
# 6      (the, DT)     (was, VBD)          1         serving              0
# 7  (serving, NN)    (worst, RB)          0              be              0
# 8     (was, VBD)                         0             bad              0
#
# [9 rows x 11 columns]

# %%
df['token_freq']=''
for i in range(0,len(df)):
    df['token_freq'][i]=sen.count(df['word'][i])

# %%
df['head_word_tag']=""
for i in range(0,len(post_tag)):
    
    if(post_tag[i][0] in head_word):
        df['head_word_tag'][i]=post_tag[i][1]

# %%
df.drop(['pos_tag'], axis=1)
# Out:
#       word  stopword  word_len next_words prev_words pre_word_tag  \
# 0      the         1         0       food
# 1     food         0         1        was        the           DT
# 2      was         1         0       best       food           NN
# 3     best         0         1        but        was          VBD
# 4      but         1         0        the       best          RBS
# 5      the         1         0    serving        but           CC
# 6  serving         0         1        was        the           DT
# 7      was         1         0      worst    serving           NN
# 8    worst         0         1                   was          VBD
#
#   post_word_tag  head_word lematized_words ortho_features token_freq  \
# 0            NN          0             the              0          2
# 1           VBD          1            food              0          1
# 2           RBS          0              be              0          2
# 3            CC          0            best              0          1
# 4            DT          0             but              0          1
# 5            NN          0             the              0          2
# 6           VBD          1         serving              0          1
# 7            RB          0              be              0          2
# 8                        0             bad              0          1
#
#   head_word_tag  pos
# 0                 DT
# 1            NN   NN
# 2                VBD
# 3                RBS
# 4                 CC
# 5                 DT
# 6            NN   NN
# 7                VBD
# 8                 RB
#
# [9 rows x 13 columns]

# %%
from sklearn.preprocessing import LabelEncoder
class MultiColumnLabelEncoder:
    def __init__(self,columns = None):
        self.columns = columns # array of column names to encode

    def fit(self,X,y=None):
        return self # not relevant here

    def transform(self,X):
        '''
        Transforms columns of X specified in self.columns using
        LabelEncoder(). If no columns specified, transforms all
        columns in X.
        '''
        output = X.copy()
        if self.columns is not None:
            for col in self.columns:
                output[col] = LabelEncoder().fit_transform(output[col])
        else:
            for colname,col in output.iteritems():
                output[colname] = LabelEncoder().fit_transform(col)
        return output

    def fit_transform(self,X,y=None):
        return self.fit(X,y).transform(X)

# %%
df.drop(['pos_tag'], axis=1)
# Out:
#       word  stopword  word_len next_words prev_words pre_word_tag  \
# 0      the         1         0       food
# 1     food         0         1        was        the           DT
# 2      was         1         0       best       food           NN
# 3     best         0         1        but        was          VBD
# 4      but         1         0        the       best          RBS
# 5      the         1         0    serving        but           CC
# 6  serving         0         1        was        the           DT
# 7      was         1         0      worst    serving           NN
# 8    worst         0         1                   was          VBD
#
#   post_word_tag  head_word lematized_words ortho_features token_freq  \
# 0            NN          0             the              0          2
# 1           VBD          1            food              0          1
# 2           RBS          0              be              0          2
# 3            CC          0            best              0          1
# 4            DT          0             but              0          1
# 5            NN          0             the              0          2
# 6           VBD          1         serving              0          1
# 7            RB          0              be              0          2
# 8                        0             bad              0          1
#
#   head_word_tag  pos
# 0                 DT
# 1            NN   NN
# 2                VBD
# 3                RBS
# 4                 CC
# 5                 DT
# 6            NN   NN
# 7                VBD
# 8                 RB
#
# [9 rows x 13 columns]

# %%
MultiColumnLabelEncoder(columns = ['word','next_words','prev_words','pre_word_tag','post_word_tag','lematized_words','head_word_tag','pos']).fit_transform(df)
# Out:
#    word  stopword        pos_tag  word_len  next_words  prev_words  \
# 0     4         1      (the, DT)         0           3           0
# 1     2         0     (food, NN)         1           6           5
# 2     5         1     (was, VBD)         0           1           3
# 3     0         0    (best, RBS)         1           2           6
# 4     1         1      (but, CC)         0           5           1
# 5     4         1      (the, DT)         0           4           2
# 6     3         0  (serving, NN)         1           6           5
# 7     5         1     (was, VBD)         0           7           4
# 8     6         0    (worst, RB)         1           0           6
#
#    pre_word_tag  post_word_tag  head_word  lematized_words ortho_features  \
# 0             0              3          0                6              0
# 1             2              6          1                4              0
# 2             3              5          0                1              0
# 3             5              1          0                2              0
# 4             4              2          0                3              0
# 5             1              3          0                6              0
# 6             2              6          1                5              0
# 7             3              4          0                1              0
# 8             5              0          0                0              0
#
#   token_freq  head_word_tag  pos
# 0          2              0    1
# 1          1              1    2
# 2          2              0    5
# 3          1              0    4
# 4          1              0    0
# 5          2              0    1
# 6          1              1    2
# 7          2              0    5
# 8          1              0    3
#
# [9 rows x 14 columns]

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words  \
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
#   pre_word_tag post_word_tag  head_word lematized_words ortho_features  \
# 0                         NN          0             the              0
# 1           DT           VBD          1            food              0
# 2           NN           RBS          0              be              0
# 3          VBD            CC          0            best              0
# 4          RBS            DT          0             but              0
# 5           CC            NN          0             the              0
# 6           DT           VBD          1         serving              0
# 7           NN            RB          0              be              0
# 8          VBD                        0             bad              0
#
#   token_freq head_word_tag  pos
# 0          2                 DT
# 1          1            NN   NN
# 2          2                VBD
# 3          1                RBS
# 4          1                 CC
# 5          2                 DT
# 6          1            NN   NN
# 7          2                VBD
# 8          1                 RB
#
# [9 rows x 14 columns]

# %%
df
# Out:
#       word  stopword        pos_tag  word_len next_words prev_words  \
# 0      the         1      (the, DT)         0       food
# 1     food         0     (food, NN)         1        was        the
# 2      was         1     (was, VBD)         0       best       food
# 3     best         0    (best, RBS)         1        but        was
# 4      but         1      (but, CC)         0        the       best
# 5      the         1      (the, DT)         0    serving        but
# 6  serving         0  (serving, NN)         1        was        the
# 7      was         1     (was, VBD)         0      worst    serving
# 8    worst         0    (worst, RB)         1                   was
#
#   pre_word_tag post_word_tag  head_word lematized_words ortho_features  \
# 0                         NN          0             the              0
# 1           DT           VBD          1            food              0
# 2           NN           RBS          0              be              0
# 3          VBD            CC          0            best              0
# 4          RBS            DT          0             but              0
# 5           CC            NN          0             the              0
# 6           DT           VBD          1         serving              0
# 7           NN            RB          0              be              0
# 8          VBD                        0             bad              0
#
#   token_freq head_word_tag  pos
# 0          2                 DT
# 1          1            NN   NN
# 2          2                VBD
# 3          1                RBS
# 4          1                 CC
# 5          2                 DT
# 6          1            NN   NN
# 7          2                VBD
# 8          1                 RB
#
# [9 rows x 14 columns]
